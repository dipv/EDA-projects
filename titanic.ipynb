# %%
import pandas as pd
df=pd.read_csv("Titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df['Cabin'].shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cabin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ...

# %%
df['Cabin'].isna().mean()*100
# Out:
# 77.10437710437711

# %%
df=df.drop(columns=['Cabin'])

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cabin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ...

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())  # replace NaN with mean age

# %%
df['Age'].unique()
# Out:
# array([34.5       , 47.        , 62.        , 27.        , 22.        ,
#        14.        , 30.        , 26.        , 18.        , 21.        ,
#        30.27259036, 46.        , 23.        , 63.        , 24.        ,
#        35.        , 45.        , 55.        ,  9.        , 48.        ,
#        50.        , 22.5       , 41.        , 33.        , 18.5       ,
#        25.        , 39.        , 60.        , 36.        , 20.        ,
#        28.        , 10.        , 17.        , 32.        , 13.        ,
#        31.        , 29.        , 28.5       , 32.5       ,  6.        ,
#        67.        , 49.        ,  2.        , 76.        , 43.        ,
#        16.        ,  1.        , 12.        , 42.        , 53.        ,
#        26.5       , 40.        , 61.        , 60.5       ,  7.        ,
#        15.        , 54.        , 64.        , 37.        , 34.        ,
#        11.5       ,  8.        ,  0.33      , 38.        , 57.        ,
# ...

# %%
df=df.dropna(subset=['Cabin'])
df['Cabin'].unique()
# Out:
# array(['B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D34', 'D19',
#        'A9', 'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53', 'D43',
#        'C130', 'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116', 'F',
#        'A29', 'G6', 'C6', 'C28', 'C51', 'E46', 'C54', 'C97', 'D22', 'B10',
#        'F4', 'E45', 'E52', 'D30', 'B58 B60', 'E34', 'C62 C64', 'A11',
#        'B11', 'C80', 'F33', 'C85', 'D37', 'C86', 'D21', 'C89', 'F E46',
#        'A34', 'D', 'B26', 'C22 C26', 'B69', 'C32', 'B78', 'F E57', 'F2',
#        'A18', 'C106', 'B51 B53 B55', 'D10 D12', 'E60', 'E50', 'E39 E41',
#        'B52 B54 B56', 'C39', 'B24', 'D28', 'B41', 'C7', 'D40', 'D38',
#        'C105'], dtype=object)

# %%
df['Cabin'].isna().sum()
# Out:
# 0

# %%
df.head()
# Out:
#     PassengerId  Pclass                                               Name  \
# 12          904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24          916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26          918       1                       Ostby, Miss. Helene Ragnhild
# 28          920       1                            Brady, Mr. John Bertram
#
#        Sex   Age  SibSp  Parch       Ticket      Fare            Cabin  \
# 12  female  23.0      1      0        21228   82.2667              B45
# 14  female  47.0      1      0  W.E.P. 5734   61.1750              E31
# 24  female  48.0      1      3     PC 17608  262.3750  B57 B59 B63 B66
# 26  female  22.0      0      1       113509   61.9792              B36
# 28    male  41.0      0      0       113054   30.5000              A21
#
#    Embarked
# 12        S
# 14        S
# 24        C
# 26        C
# 28        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
survival_by_gender = df.groupby('Sex')['Survived'].mean()
print(survival_by_gender)
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df=df['Pclass'].sort_values()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Pclass'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df=df['Pclass'].sort_values()
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Cabin'].isna().mean()*100
# Out:
# 77.10437710437711

# %%
df['Cabin'].shape
# Out:
# (891,)

# %%
df=df.drop('Cabin')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df=df.drop('Cabin')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df.drop(columns="Cabin")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].isna().mean()*100
# Out:
# 19.865319865319865

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Age'].isna().mean()*100
# Out:
# 0.0

# %%
surv_gender=df.groupby('Sex')['Survived'].mean()
print(surv_gender)
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
surv_class=df.groupby('Pclass')['Survived'].mean()
print(surv_class)
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
sorting = df.sort_values(by=['Len', 'Age'], ascending=[False, True])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21952\1863403387.py in ?()
# ----> 1 sorting = df.sort_values(by=['Len', 'Age'], ascending=[False, True])
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6736                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    6737                 f" != length of by ({len(by)})"
#    6738             )
#    6739         if len(by) > 1:
# -> 6740             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6741
#    6742             # need to rewrap columns in Series to apply key function
#    6743             if key is not None:
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(.0)
# -> 6740     def sort_values(
#    6741         self,
# ...

# %%
          #Barplot
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="Sex", y="Survived", data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.histplot(df['Age'], bins=10, kde=True, color="blue", label="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df['Sex'], color="blue", label="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %%
sns.histplot(df['Sex'], bins=10, kde=True, color="blue", label="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %%
sns.histplot(df['Age'],bins=15, kde=True, color="blue", label="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df['Age'].agg([min,max])
# Out:
# min     0.42
# max    80.00
# Name: Age, dtype: float64

# %%
df['Age'].count()
# Out:
# 714

# %%
df['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
sns.histplot(x=df['Age'], y=df['Fare'], cmap='viridis')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>
